# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import os
from PIL import Image
from IPython.display import display

#filtering harmless warnings
import warnings
warnings.filterwarnings("ignore")

# %%
path = "C:/Works/Personal/repo/DatasetFolder/Cats_Dogs_Dataset/CATS_DOGS/"
img_names = []
for folder, subfolders, filenames in os.walk(path):
    for img in filenames:
        img_names.append(folder+'\\'+img)

# %%
len(img_names)
# Out:
# 24994

# %%
img_sizes = []
rejected = []

for item in img_names:
    try:
        with Image.open(item) as img:
            img_sizes.append(img.size)
    except:
        rejected.append(item)
        
print(f'Images:  {len(img_sizes)}')
print(f'Rejects: {len(rejected)}')
# Out:
# Images:  24994
# Rejects: 0

# %%
#statistics on images dimensions
df = pd.DataFrame(img_sizes)
df[0].describe()
# Out:
# count    24994.000000
# mean       404.493518
# std        108.941802
# min         42.000000
# 25%        323.000000
# 50%        448.000000
# 75%        500.000000
# max        500.000000
# Name: 0, dtype: float64

# %%
df[1].describe()
# Out:
# count    24994.000000
# mean       361.037129
# std         96.936811
# min         33.000000
# 25%        302.000000
# 50%        375.000000
# 75%        421.000000
# max        500.000000
# Name: 1, dtype: float64

# %%
#transformation on images.....

# %%
dog = Image.open(path+'train/DOG/14.jpg')
print(dog.size)
display(dog)
# Out:
# (500, 387)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x387 at 0x17C205569B0>

# %%
#transforming to a tensor object
transform = transforms.Compose([ #Compose allows to apply multiple transformations
    transforms.ToTensor()
])
im = transform(dog)
print(im.shape)
plt.imshow(np.transpose(im.numpy(), (1, 2, 0))); #transposing to display with matplotlib library
# Out:
# torch.Size([3, 387, 500])

# %%
transform = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.CenterCrop(250),
    transforms.ToTensor()
])
im = transform(dog)
print(im.shape)
plt.imshow(np.transpose(im.numpy(), (1, 2, 0)));
# Out:
# torch.Size([3, 250, 250])
